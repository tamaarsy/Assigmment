# %% [markdown]
# ## 1. Buatlah vektor dibwah ini dengan python:

# %%
import numpy as np

vector1 = np.array([17,22,19])
vector1
# Out:
# array([17, 22, 19])

# %% [markdown]
# ## 2. Diberikan 3 bauh vector 3 dimensi:
# ## A = [17,22,19] B = [10,20,11] C = [5,12,9]

# %%
A = np.array([17,22,19]) 
B = np.array([10,20,11]) 
C = np.array([5,12,9])

# %%
# petambahan
A + B
# Out:
# array([27, 42, 30])

# %%
#pengurangan
B-C
# Out:
# array([5, 8, 2])

# %%
# A dot C
A.dot(C)
# Out:
# 520

# %%
# A x B
A * B
# Out:
# array([170, 440, 209])

# %%
np.linalg.norm(A)
# Out:
# 33.67491648096547

# %%
result = A.dot(B)

# %%
#mencari sudut
theta = np.arccos(result/(np.linalg.norm(A) * np.linalg.norm(B)))
theta
# Out:
# 0.21971776576153962

# %% [markdown]
# ##  3 .Buatlahplot darivector berikutinikedalambidang2D: 𝒖=[2,5],𝒗=[3,1]

# %%
x = np.array([2, 5])
v = np.array([3, 1])

# %%
import matplotlib.pyplot as plt

plt.plot(x)

# %%
plt.plot(v)
